# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.104.1)
# Requirement already satisfied: python-dotenv in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from anthropic import Anthropic
load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message= {"role": "user","content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant","content": text}
    messages.append(assistant_message)

def chat(messages):

    with client.messages.stream(
        model=model,
        max_tokens=1000,
        messages=messages
    ) as stream:
        for text in stream.text_stream:
            print(text, end="", flush=True)
    print()  # newline after response
    return stream.get_final_message()

messages = []

# %%
add_assistant_message(messages, "Hello! How can I assist you today?")

# %%
while True:
    user_input = input("You: ")
    print(" you entered: ", user_input)
    add_user_message(messages, user_input)
    print("assistant : " , end = "" )
    chat(messages)
    add_assistant_message(messages,)
# Out:
#  you entered:  write an short easy on inida
# # Essay on Python Programming
#
# Python is one of the most popular and versatile programming languages in the world today. Created by Guido van Rossum and first released in 1991, Python has grown to become a favorite among beginners and experienced programmers alike.
#
# ## Why Python is Popular
#
# Python's popularity stems from its simple and readable syntax. Unlike many programming languages that use complex symbols and structures, Python reads almost like English. This makes it an excellent choice for those just starting their programming journey. The language emphasizes code readability, allowing developers to express concepts in fewer lines of code compared to languages like Java or C++.
#
# ## Applications of Python
#
# Python is remarkably versatile and finds applications across numerous fields. In web development, frameworks like Django and Flask power thousands of websites. Data scientists rely heavily on Python, using libraries such as Pandas, NumPy, and Matplotlib for data analysis and visualization. The field of artificial intelligence and machine learning has embraced Python through powerful tools like TensorFlow and PyTorch. Additionally, Python is used in automation, game development, cybersecurity, and scientific computing.
#
# ## Conclusion
#
# Python's combination of simplicity, power, and versatility has cemented its position as a leading programming language. Whether you're building websites, analyzing data, or creating artificial intelligence systems, Python provides the tools and community support to turn ideas into reality.
#
# ---
#
# # Short Essay on India
#
# India is a vast and diverse country located in South Asia, home to over 1.4 billion people, making it the world's most populous nation. With a history spanning thousands of years, India is known as the birthplace of ancient civilizations and major religions including Hinduism, Buddhism, Jainism, and Sikhism.
#
# ## Cultural Diversity
#
# India's greatest strength lies in its incredible diversity. The country boasts 22 officially recognized languages, with Hindi and English serving as the primary languages of government. From the snow-capped Himalayas in the north to the tropical beaches of the south, India's geography is as varied as its culture. Each state has its own distinct traditions, festivals, cuisines, and art forms.
#
# ## Economic Growth
#
# Since liberalizing its economy in 1991, India has emerged as one of the world's fastest-growing major economies. The country is a global leader in information technology, pharmaceuticals, and space research. Cities like Bangalore, Mumbai, and Hyderabad have become international technology hubs.
#
# ## Challenges and Future
#
# Despite its progress, India faces challenges including poverty, infrastructure development, and environmental concerns. However, with its young population, democratic values, and entrepreneurial spirit, India continues to play an increasingly important role on the world stage.
#
# India remains a land of contrasts where ancient traditions coexist with modern innovation, making it one of the most fascinating countries in the world.
# assistant :  None
# # Essay on Python Programming
#
# Python is one of the most popular and versatile programming languages in the world today. Created by Guido van Rossum and first released in 1991, Python has grown to become a favorite among beginners and experienced developers alike.
#
# ## Why Python is Popular
#
# Python's popularity stems from its simple, readable syntax that closely resembles the English language. This makes it an excellent choice for those new to programming. Unlike many other languages that require complex syntax and strict formatting, Python emphasizes code readability and allows programmers to express concepts in fewer lines of code.
#
# ## Key Features
#
# Python is an interpreted, high-level language with dynamic typing. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library provides tools for everything from file operations to web development, earning it the nickname "batteries included."
#
# ## Applications
#
# Python's versatility is remarkable. It powers web applications through frameworks like Django and Flask, drives data science and machine learning with libraries like NumPy and TensorFlow, automates tasks, develops games, and even controls hardware in IoT projects. Major companies like Google, Netflix, and NASA use Python extensively.
#
# ## Conclusion
#
# Python continues to evolve and grow, making it an excellent investment for anyone interested in programming. Its simplicity, power, and wide range of applications ensure it will remain relevant for years to come.
#
# ---
#
# # Short Essay on India
#
# India is a vast and diverse country located in South Asia, home to over 1.4 billion people, making it the world's most populous nation. With a history spanning thousands of years, India is one of the world's oldest civilizations.
#
# ## Rich Cultural Heritage
#
# India is known for its incredible cultural diversity. It is the birthplace of major religions including Hinduism, Buddhism, Jainism, and Sikhism. The country celebrates numerous festivals, speaks over 700 languages, and boasts varied cuisines, traditional arts, and architectural marvels like the Taj Mahal.
#
# ## Modern India
#
# Since gaining independence from British rule in 1947, India has transformed into the world's largest democracy. Today, it is a rapidly growing economy and a major hub for technology, pharmaceuticals, and services. Cities like Bangalore have become global IT centers, while Bollywood produces the most films annually of any country.
#
# ## Challenges and Opportunities
#
# Despite its progress, India faces challenges including poverty, infrastructure development, and environmental concerns. However, with its young population, growing middle class, and entrepreneurial spirit, India continues to play an increasingly important role on the global stage.
#
# India's blend of ancient traditions and modern aspirations makes it a fascinating and dynamic nation.
#  you entered:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(" you entered: ", user_input)
#       4 add_user_message(messages, user_input)
# ----> 5 print("assistant : " , chat(messages))
#       6 add_assistant_message(messages, chat(messages))
#
# Cell In[4], line 11, in chat(messages)
#       9 def chat(messages):
# ---> 11     with client.messages.stream(
#      12         model=model,
#      13         max_tokens=1000,
#      14         messages=messages
#      15     ) as stream:
#      16         for text in stream.text_stream:
#      17             print(text, end="", flush=True)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/lib/streaming/_messages.py:167, in MessageStreamManager.__enter__(self)
#     166 def __enter__(self) -> MessageStream[ResponseFormatT]:
# --> 167     raw_stream = self.__api_request()
#     168     self.__stream = MessageStream(raw_stream, output_format=self.__output_format)
#     169     return self.__stream
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.3.content: Input should be a valid array'}, 'request_id': 'req_011CbKZyJGAujkk8wWiknRKr'}

# %%
print(messages)
# Out:
# [{'role': 'assistant', 'content': 'Hello! How can I assist you today?'}, {'role': 'user', 'content': 'write an essay about python programing?'}, {'role': 'user', 'content': 'write an short easy on inida'}, {'role': 'assistant', 'content': None}, {'role': 'user', 'content': ''}]
