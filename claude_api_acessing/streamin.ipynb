# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.104.1)
# Requirement already satisfied: python-dotenv in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from anthropic import Anthropic
load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message= {"role": "user","content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant","content": text}
    messages.append(assistant_message)

def chat(messages):
    
    with client.messages.stream(
        model=model,
        max_tokens=1000,
        messages=messages
    ) as stream:
        for text in stream.text_stream:
            print(text, end="", flush=True)
            
        final = stream.get_final_message()

    print()
    assistant_text = final.content[0].text
    add_assistant_message(messages, assistant_text)  # store in context
    return assistant_text

messages = []

# %%
while True:
    user_input = input("You: ")
    print(" you entered: ", user_input)
    add_user_message(messages, user_input)
    print("assistant : " , end = "" )
    chat(messages)
# Out:
#  you entered:  hello write an essay about human
# assistant : # The Human Experience: A Journey Through Nature, Culture, and Consciousness
#
# ## Introduction
#
# To write about humans is to attempt capturing the ocean in a teacup—an endeavor both humbling and necessary. Humans (*Homo sapiens*) represent one of Earth's most paradoxical species: physically vulnerable yet technologically dominant, individually mortal yet collectively immortal through culture, capable of profound compassion and terrible cruelty. This essay explores what it means to be human through our biological origins, cognitive abilities, social nature, and the unique position we occupy in the natural world.
#
# ## Our Biological Foundation
#
# Humans emerged approximately 300,000 years ago in Africa, the product of millions of years of evolutionary refinement. We are primates, sharing approximately 98.8% of our DNA with chimpanzees, yet that small genetic difference has produced remarkable distinctions. Our upright posture freed our hands for tool use; our opposable thumbs enabled precise manipulation; our vocal anatomy allowed complex speech.
#
# Yet humans are, in many ways, physically unremarkable. We lack the strength of gorillas, the speed of cheetahs, the flight of birds, or the aquatic mastery of dolphins. We are born helpless, requiring years of care before independence—far longer than most species. This extended childhood, however, became one of our greatest advantages, providing time for the complex learning that would become humanity's signature trait.
#
# ## The Power of the Human Mind
#
# What truly distinguishes humans is our brain—particularly our highly developed prefrontal cortex. This biological marvel enables abstract thinking, long-term planning, moral reasoning, and self-awareness. We are the species that asks "why?" and seeks to understand not just how things work, but what they mean.
#
# Human consciousness remains one of science's greatest mysteries. We experience subjective awareness—the feeling of being someone, the interior life of thoughts, emotions, memories, and dreams. We are capable of metacognition: thinking about thinking, knowing that we know. This self-reflective consciousness allows us to imagine futures that don't exist and learn from pasts we never experienced.
#
# Our capacity for symbolic thought sets us apart. We create and manipulate symbols—words, numbers, musical notes, mathematical equations—that represent things beyond themselves. This ability underlies language, art, science, and culture itself. A string of sounds becomes a poem; marks on paper become a symphony; abstract symbols become quantum physics.
#
# ## The Social Animal
#
# Aristotle called humans "political animals," recognizing that our social nature is fundamental to our identity. We are born into relationships and depend on them throughout life. Human infants require care; human adults seek connection; human elders pass down wisdom. We are wired for empathy, cooperation, and communication.
#
# Language represents our most sophisticated social tool. Unlike animal communication systems, human language is generative and infinitely creative. We can discuss things absent in space and time, express hypothetical scenarios, craft fiction, tell lies, and articulate abstract concepts like justice or love. Language allows each generation to inherit the accumulated knowledge of all who came before.
#
# Our social structures have evolved from small hunter-gatherer bands to cities of millions, from simple kinship groups to complex nation-states. We create institutions, laws, and customs that regulate behavior and enable large-scale cooperation among strangers. This ability to organize collectively has allowed humans to accomplish what no individual could: build cities, create technologies, develop sciences, and reshape the planet itself.
#
# ## Culture: Humanity's Greatest Innovation
#
# If our biological evolution gave us the capacity for culture, culture has become our primary means of adaptation. Culture encompasses everything humans learn and transmit socially: knowledge, beliefs, arts, laws, customs, and technologies. It is the software to our biological hardware.
#
# Cultural evolution operates far faster than biological evolution. Genetic changes require generations; cultural changes can occur in years or even days. The smartphone in your pocket represents technologies that didn't exist decades ago, yet they've fundamentally transformed human life. This is culture's power: accumulated, shared, and rapidly transmitted knowledge.
#
# Human cultures are dizzyingly diverse. From the Arctic to the Amazon, from isolated islands to sprawling metropolises, humans have created thousands of distinct ways of life, each with unique languages, belief systems, artistic traditions, and social organizations. This cultural diversity demonstrates human adaptability and creativity while reminding us that many aspects of our lives we consider "natural" are actually cultural constructions.
#
# ## Creativity and Meaning-Making
#
# Humans are compulsive meaning-makers. We see patterns, tell stories, create narratives that explain our experiences. We are the species that makes art not for survival but for beauty, expression
#  you entered:
# assistant :
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 6
#       4 add_user_message(messages, user_input)
#       5 print("assistant : " , end = "" )
# ----> 6 chat(messages)
#
# Cell In[3], line 11, in chat(messages)
#       9 def chat(messages):
#      10     full_response = ""
# ---> 11     with client.messages.stream(
#      12         model=model,
#      13         max_tokens=1000,
#      14         messages=messages
#      15     ) as stream:
#      16         for text in stream.text_stream:
#      17             print(text, end="", flush=True)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/lib/streaming/_messages.py:167, in MessageStreamManager.__enter__(self)
#     166 def __enter__(self) -> MessageStream[ResponseFormatT]:
# --> 167     raw_stream = self.__api_request()
#     168     self.__stream = MessageStream(raw_stream, output_format=self.__output_format)
#     169     return self.__stream
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.2: user messages must have non-empty content'}, 'request_id': 'req_011CbKb19D8cZducV6e9Hj1n'}

# %%
print(messages)
# Out:
# [{'role': 'user', 'content': 'hello write an essay about human'}, {'role': 'assistant', 'content': '# The Human Experience: A Journey Through Nature, Culture, and Consciousness\n\n## Introduction\n\nTo write about humans is to attempt capturing the ocean in a teacup—an endeavor both humbling and necessary. Humans (*Homo sapiens*) represent one of Earth\'s most paradoxical species: physically vulnerable yet technologically dominant, individually mortal yet collectively immortal through culture, capable of profound compassion and terrible cruelty. This essay explores what it means to be human through our biological origins, cognitive abilities, social nature, and the unique position we occupy in the natural world.\n\n## Our Biological Foundation\n\nHumans emerged approximately 300,000 years ago in Africa, the product of millions of years of evolutionary refinement. We are primates, sharing approximately 98.8% of our DNA with chimpanzees, yet that small genetic difference has produced remarkable distinctions. Our upright posture freed our hands for tool use; our opposable thumbs enabled precise manipulation; our vocal anatomy allowed complex speech.\n\nYet humans are, in many ways, physically unremarkable. We lack the strength of gorillas, the speed of cheetahs, the flight of birds, or the aquatic mastery of dolphins. We are born helpless, requiring years of care before independence—far longer than most species. This extended childhood, however, became one of our greatest advantages, providing time for the complex learning that would become humanity\'s signature trait.\n\n## The Power of the Human Mind\n\nWhat truly distinguishes humans is our brain—particularly our highly developed prefrontal cortex. This biological marvel enables abstract thinking, long-term planning, moral reasoning, and self-awareness. We are the species that asks "why?" and seeks to understand not just how things work, but what they mean.\n\nHuman consciousness remains one of science\'s greatest mysteries. We experience subjective awareness—the feeling of being someone, the interior life of thoughts, emotions, memories, and dreams. We are capable of metacognition: thinking about thinking, knowing that we know. This self-reflective consciousness allows us to imagine futures that don\'t exist and learn from pasts we never experienced.\n\nOur capacity for symbolic thought sets us apart. We create and manipulate symbols—words, numbers, musical notes, mathematical equations—that represent things beyond themselves. This ability underlies language, art, science, and culture itself. A string of sounds becomes a poem; marks on paper become a symphony; abstract symbols become quantum physics.\n\n## The Social Animal\n\nAristotle called humans "political animals," recognizing that our social nature is fundamental to our identity. We are born into relationships and depend on them throughout life. Human infants require care; human adults seek connection; human elders pass down wisdom. We are wired for empathy, cooperation, and communication.\n\nLanguage represents our most sophisticated social tool. Unlike animal communication systems, human language is generative and infinitely creative. We can discuss things absent in space and time, express hypothetical scenarios, craft fiction, tell lies, and articulate abstract concepts like justice or love. Language allows each generation to inherit the accumulated knowledge of all who came before.\n\nOur social structures have evolved from small hunter-gatherer bands to cities of millions, from simple kinship groups to complex nation-states. We create institutions, laws, and customs that regulate behavior and enable large-scale cooperation among strangers. This ability to organize collectively has allowed humans to accomplish what no individual could: build cities, create technologies, develop sciences, and reshape the planet itself.\n\n## Culture: Humanity\'s Greatest Innovation\n\nIf our biological evolution gave us the capacity ...
